# %%
import pandas as pd

# %%
df = pd.read_csv('StudentsPerformance.csv')

# %%
df.head() # returb the first 5 rows
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.head(7) # returb the first 7 rows
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
# ...

# %%
df.tail() # return The 5 last rows
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
df.tail(8) # return The 8 last rows
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 994    male        group A                 high school      standard
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 992                    none          55             76             76
# 993                    none          62             72             74
# 994                    none          63             63             62
# ...

# %%
df.sample() # return random row
# Out:
#      gender race/ethnicity parental level of education     lunch  \
# 403  female        group D                 high school  standard
#
#     test preparation course  math score  reading score  writing score
# 403               completed          88             99            100

# %%
df.sample(frac=0.1) # return 10% of the rows randomly
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 271    male        group C                some college      standard
# 775  female        group B            some high school  free/reduced
# 639  female        group D          associate's degree      standard
# 192  female        group B            some high school      standard
# 79   female        group E             master's degree      standard
# ..      ...            ...                         ...           ...
# 621    male        group B           bachelor's degree  free/reduced
# 441  female        group D                 high school      standard
# 243    male        group E                some college      standard
# 806  female        group D                some college  free/reduced
# 605    male        group C            some high school      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.sample(5) # return The 5 rows randomly
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 312    male        group D           bachelor's degree      standard
# 926    male        group E          associate's degree  free/reduced
# 527  female        group C                 high school  free/reduced
# 508    male        group C             master's degree      standard
# 298    male        group C                 high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 312               completed          67             61             68
# 926                    none          64             56             52
# 527                    none          36             53             43
# 508                    none          79             78             77
# 298               completed          40             46             50

# %%
df.iloc[100:110] # return 10 rows from row 100 to row 109 and all columns of these
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 100    male        group B                some college      standard
# 101    male        group D           bachelor's degree      standard
# 102  female        group D          associate's degree      standard
# 103    male        group B                 high school      standard
# 104    male        group C                some college      standard
# 105  female        group C                some college      standard
# 106  female        group D             master's degree      standard
# 107    male        group E          associate's degree      standard
# 108  female        group B          associate's degree  free/reduced
# 109  female        group B            some high school      standard
#
#     test preparation course  math score  reading score  writing score
# 100                    none          79             67             67
# ...

# %%
df.iloc[100:110, 2:5] # return 10 rows from row 100 to row 109 and return 3 columns of these (2,3,4)
# Out:
#     parental level of education         lunch test preparation course
# 100                some college      standard                    none
# 101           bachelor's degree      standard               completed
# 102          associate's degree      standard                    none
# 103                 high school      standard               completed
# 104                some college      standard               completed
# 105                some college      standard                    none
# 106             master's degree      standard                    none
# 107          associate's degree      standard               completed
# 108          associate's degree  free/reduced                    none
# 109            some high school      standard                    none

# %%
df.iloc[104:778]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 104    male        group C                some college      standard
# 105  female        group C                some college      standard
# 106  female        group D             master's degree      standard
# 107    male        group E          associate's degree      standard
# 108  female        group B          associate's degree  free/reduced
# ..      ...            ...                         ...           ...
# 773  female        group C           bachelor's degree  free/reduced
# 774    male        group B                some college      standard
# 775  female        group B            some high school  free/reduced
# 776  female        group B                 high school      standard
# 777  female        group C                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.loc[[150, 777, 600, 105], ['gender', 'math score', 'lunch']]
# Out:
#      gender  math score         lunch
# 150    male          62      standard
# 777  female          35  free/reduced
# 600  female          54      standard
# 105  female          58      standard

# %%
df.loc[100:200, ['gender', 'parental level of education', 'reading score', 'writing score']]
# Out:
#      gender parental level of education  reading score  writing score
# 100    male                some college             67             67
# 101    male           bachelor's degree             74             74
# 102  female          associate's degree             91             89
# 103    male                 high school             44             47
# 104    male                some college             86             90
# ..      ...                         ...            ...            ...
# 196    male            some high school             69             65
# 197    male                 high school             56             51
# 198  female                some college             53             55
# 199  female           bachelor's degree             79             76
# 200  female          associate's degree             84             86
#
# [101 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
df.drop(columns=['lunch'])
# Out:
#      gender race/ethnicity parental level of education  \
# 0    female        group B           bachelor's degree
# 1    female        group C                some college
# 2    female        group B             master's degree
# 3      male        group A          associate's degree
# 4      male        group C                some college
# ..      ...            ...                         ...
# 995  female        group E             master's degree
# 996    male        group C                 high school
# 997  female        group C                 high school
# 998  female        group D                some college
# 999  female        group D                some college
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
df.drop(columns=['lunch'], inplace= True) # drop column Lunch from table

# %%
df.info() # return all info without column lunch
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   test preparation course      1000 non-null   object
#  4   math score                   1000 non-null   int64
#  5   reading score                1000 non-null   int64
#  6   writing score                1000 non-null   int64
# dtypes: int64(3), object(4)
# memory usage: 54.8+ KB

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education test preparation course  \
# 0  female        group B           bachelor's degree                    none
# 1  female        group C                some college               completed
# 2  female        group B             master's degree                    none
# 3    male        group A          associate's degree                    none
# 4    male        group C                some college                    none
#
#    math score  reading score  writing score
# 0          72             72             74
# 1          69             90             88
# 2          90             95             93
# 3          47             57             44
# 4          76             78             75

# %%
df.drop(index=2) # drop row 2 from table
# Out:
#      gender race/ethnicity parental level of education  \
# 0    female        group B           bachelor's degree
# 1    female        group C                some college
# 3      male        group A          associate's degree
# 4      male        group C                some college
# 5    female        group B          associate's degree
# ..      ...            ...                         ...
# 995  female        group E             master's degree
# 996    male        group C                 high school
# 997  female        group C                 high school
# 998  female        group D                some college
# 999  female        group D                some college
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 3                      none          47             57             44
# ...

# %%
df.drop(index=2, inplace= True) # drop row 2 from table

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education test preparation course  \
# 0  female        group B           bachelor's degree                    none
# 1  female        group C                some college               completed
# 3    male        group A          associate's degree                    none
# 4    male        group C                some college                    none
# 5  female        group B          associate's degree                    none
#
#    math score  reading score  writing score
# 0          72             72             74
# 1          69             90             88
# 3          47             57             44
# 4          76             78             75
# 5          71             83             78

# %%
df.isna()
# Out:
#      gender  race/ethnicity  parental level of education  \
# 0     False           False                        False
# 1     False           False                        False
# 3     False           False                        False
# 4     False           False                        False
# 5     False           False                        False
# ..      ...             ...                          ...
# 995   False           False                        False
# 996   False           False                        False
# 997   False           False                        False
# 998   False           False                        False
# 999   False           False                        False
#
#      test preparation course  math score  reading score  writing score
# 0                      False       False          False          False
# 1                      False       False          False          False
# ...

# %%
df.isna().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 3      False
# 4      False
# 5      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 999, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df['math score'] # return in series form
# Out:
# 0      72
# 1      69
# 3      47
# 4      76
# 5      71
#        ..
# 995    88
# 996    62
# 997    59
# 998    68
# 999    77
# Name: math score, Length: 999, dtype: int64

# %%
df[['math score']] # return in dataframe form
# Out:
#      math score
# 0            72
# 1            69
# 3            47
# 4            76
# 5            71
# ..          ...
# 995          88
# 996          62
# 997          59
# 998          68
# 999          77
#
# [999 rows x 1 columns]

# %%
Q1 = df['math score'].quantile(0.25)
Q3 = df['math score'].quantile(0.75)

IQR = Q3 - Q1

UB = Q3 + 1.5 * IQR

LB = Q1 - 1.5 * IQR

# %%
LB, UB
# Out:
# (27.0, 107.0)

# %%
df[(df['math score'] > LB) & (df['math score'] < UB)]
# Out:
#      gender race/ethnicity parental level of education  \
# 0    female        group B           bachelor's degree
# 1    female        group C                some college
# 3      male        group A          associate's degree
# 4      male        group C                some college
# 5    female        group B          associate's degree
# ..      ...            ...                         ...
# 995  female        group E             master's degree
# 996    male        group C                 high school
# 997  female        group C                 high school
# 998  female        group D                some college
# 999  female        group D                some college
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 3                      none          47             57             44
# ...

# %%
df[['gender']]
# Out:
#      gender
# 0    female
# 1    female
# 3      male
# 4      male
# 5    female
# ..      ...
# 995  female
# 996    male
# 997  female
# 998  female
# 999  female
#
# [999 rows x 1 columns]

# %%
df['gender'].value_counts() # return the number of values in column gender
# Out:
# gender
# female    517
# male      482
# Name: count, dtype: int64

# %%
df['gender'].value_counts(normalize= True)
# Out:
# gender
# female    0.517518
# male      0.482482
# Name: proportion, dtype: float64

# %%
df['gender'].value_counts(normalize= True) * 100
# Out:
# gender
# female    51.751752
# male      48.248248
# Name: proportion, dtype: float64

# %%
df[['race/ethnicity']]
# Out:
#     race/ethnicity
# 0          group B
# 1          group C
# 3          group A
# 4          group C
# 5          group B
# ..             ...
# 995        group E
# 996        group C
# 997        group C
# 998        group D
# 999        group D
#
# [999 rows x 1 columns]

# %%
df['race/ethnicity'].value_counts()
# Out:
# race/ethnicity
# group C    319
# group D    262
# group B    189
# group E    140
# group A     89
# Name: count, dtype: int64

# %%
df['race/ethnicity'].unique()
# Out:
# array(['group B', 'group C', 'group A', 'group D', 'group E'],
#       dtype=object)

# %%
df['race/ethnicity'].nunique()
# Out:
# 5

# %%
df['parental level of education'].value_counts()
# Out:
# parental level of education
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        58
# Name: count, dtype: int64

# %%
df.columns.value_counts(normalize=True)
# Out:
# gender                         0.142857
# race/ethnicity                 0.142857
# parental level of education    0.142857
# test preparation course        0.142857
# math score                     0.142857
# reading score                  0.142857
# writing score                  0.142857
# Name: proportion, dtype: float64

# %%
df['test preparation course'].value_counts(normalize=True) * 100
# Out:
# test preparation course
# none         64.2
# completed    35.8
# Name: proportion, dtype: float64

# %%
df['math score'].value_counts()
# Out:
# math score
# 65    36
# 62    35
# 69    32
# 59    32
# 61    27
#       ..
# 24     1
# 28     1
# 33     1
# 18     1
# 8      1
# Name: count, Length: 81, dtype: int64

# %%
df['math score'].value_counts().head(10)
# Out:
# math score
# 65    36
# 62    35
# 69    32
# 59    32
# 61    27
# 73    27
# 63    26
# 67    26
# 68    26
# 71    26
# Name: count, dtype: int64

# %%
df['math score'].describe()
# Out:
# count    1000.00000
# mean       66.08900
# std        15.16308
# min         0.00000
# 25%        57.00000
# 50%        66.00000
# 75%        77.00000
# max       100.00000
# Name: math score, dtype: float64

# %%
df['reading score'].describe()
# Out:
# count    1000.000000
# mean       69.169000
# std        14.600192
# min        17.000000
# 25%        59.000000
# 50%        70.000000
# 75%        79.000000
# max       100.000000
# Name: reading score, dtype: float64

# %%
df['writing score'].describe()
# Out:
# count    1000.000000
# mean       68.054000
# std        15.195657
# min        10.000000
# 25%        57.750000
# 50%        69.000000
# 75%        79.000000
# max       100.000000
# Name: writing score, dtype: float64

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.groupby(['race/ethnicity'])['gender'].value_counts()
# Out:
# race/ethnicity  gender
# group A         male       53
#                 female     36
# group B         female    104
#                 male       86
# group C         female    180
#                 male      139
# group D         male      133
#                 female    129
# group E         male       71
#                 female     69
# Name: count, dtype: int64

# %%
df.groupby(['race/ethnicity'])['math score'].mean()
# Out:
# race/ethnicity
# group A    61.629213
# group B    63.452632
# group C    64.463950
# group D    67.362595
# group E    73.821429
# Name: math score, dtype: float64

# %%
df.groupby(['race/ethnicity'])['math score'].max()
# Out:
# race/ethnicity
# group A    100
# group B     97
# group C     98
# group D    100
# group E    100
# Name: math score, dtype: int64

# %%
df.groupby(['race/ethnicity'])['math score'].min()
# Out:
# race/ethnicity
# group A    28
# group B     8
# group C     0
# group D    26
# group E    30
# Name: math score, dtype: int64

# %%
df.groupby(['race/ethnicity'])['math score'].sum()
# Out:
# race/ethnicity
# group A     5485
# group B    12056
# group C    20564
# group D    17649
# group E    10335
# Name: math score, dtype: int64

# %%
df.groupby(['race/ethnicity'])['math score'].std()
# Out:
# race/ethnicity
# group A    14.523008
# group B    15.468191
# group C    14.852666
# group D    13.769386
# group E    15.534259
# Name: math score, dtype: float64

# %%
bad_scores = df[(df['math score'] < 50) & (df['reading score'] < 50) & (df['writing score'] < 50)]

# %%
bad_scores
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 7      male        group B                some college  free/reduced
# 17   female        group B            some high school  free/reduced
# 18     male        group C             master's degree  free/reduced
# 33     male        group D                some college      standard
# 55   female        group C                 high school  free/reduced
# 59   female        group C            some high school  free/reduced
# 61     male        group A            some high school  free/reduced
# 66     male        group D            some high school  free/reduced
# 74     male        group C            some high school      standard
# 75     male        group B          associate's degree  free/reduced
# 76     male        group E            some high school      standard
# 81     male        group B                 high school  free/reduced
# 84     male        group D                 high school  free/reduced
# ...

# %%
len
# Out:
# 55

# %%
bad_scores['test preparation course'].value_counts()
# Out:
# test preparation course
# none         47
# completed     8
# Name: count, dtype: int64

# %%
bad_scores['race/ethnicity'].value_counts()
# Out:
# race/ethnicity
# group B    15
# group C    15
# group D     9
# group A     9
# group E     7
# Name: count, dtype: int64

# %%
top_scores = df[(df['math score'] > 95) & (df['reading score'] > 95) & (df['writing score'] > 95)]

# %%
top_scores
# Out:
#      gender race/ethnicity parental level of education     lunch  \
# 114  female        group E           bachelor's degree  standard
# 165  female        group C           bachelor's degree  standard
# 179  female        group D            some high school  standard
# 458  female        group E           bachelor's degree  standard
# 625    male        group D                some college  standard
# 712  female        group D                some college  standard
# 717  female        group C          associate's degree  standard
# 855  female        group B           bachelor's degree  standard
# 916    male        group E           bachelor's degree  standard
# 962  female        group E          associate's degree  standard
#
#     test preparation course  math score  reading score  writing score
# 114               completed          99            100            100
# 165               completed          96            100            100
# ...

# %%
top_scores['race/ethnicity'].value_counts()
# Out:
# race/ethnicity
# group E    4
# group D    3
# group C    2
# group B    1
# Name: count, dtype: int64

# %%
top_scores['lunch'].value_counts(normalize=True)
# Out:
# lunch
# standard    1.0
# Name: proportion, dtype: float64
